# %% [markdown]
# <a href="https://colab.research.google.com/github/Kaartik7/ISSC_competition-/blob/pomegranate02-patch-1/Adi_visualizations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive

# %%
drive.mount('/drive')
# Out:
# Drive already mounted at /drive; to attempt to forcibly remount, call drive.mount("/drive", force_remount=True).

# %%
new_data = pd.read_csv('https://raw.githubusercontent.com/Kaartik7/ISSC_competition-/pomegranate02-patch-1/to%20csv/population%202008.csv')

# %%
new_data
# Out:
#                             Unnamed: 0  ...                    Unnamed: 84
# 0                        Neighbourhood  ...     After-Tax Household Income
# 1               West Humber-Clairville  ...                          63977
# 2    Mount Olive-Silverstone-Jamestown  ...                          49601
# 3         Thistletown-Beaumond Heights  ...                          54910
# 4                      Rexdale-Kipling  ...                          53779
# ..                                 ...  ...                            ...
# 136                          West Hill  ...                          49341
# 137                             Woburn  ...                          51539
# 138                      Eglinton East  ...                          44772
# 139                Scarborough Village  ...                          45109
# 140                          Guildwood  ...                          75351
#
# [141 rows x 85 columns]

# %%
names = new_data.iloc[0]

# %%
names
# Out:
# Unnamed: 0                      Neighbourhood
# Unnamed: 1                   Neighbourhood Id
# Demographics                       Total Area
# Unnamed: 3                   Total Population
# Unnamed: 4                        Pop - Males
#                             ...
# Unnamed: 80            Family Income Category
# Unnamed: 81             Average Family Income
# Unnamed: 82         Household Income Category
# Unnamed: 83          Pre-Tax Household Income
# Unnamed: 84        After-Tax Household Income
# Name: 0, Length: 85, dtype: object

# %%
new_data = new_data[1:]

# %%
new_data.columns = names

# %%
new_data
# Out:
# 0                        Neighbourhood  ...    After-Tax Household Income
# 1               West Humber-Clairville  ...                         63977
# 2    Mount Olive-Silverstone-Jamestown  ...                         49601
# 3         Thistletown-Beaumond Heights  ...                         54910
# 4                      Rexdale-Kipling  ...                         53779
# 5                     Elms-Old Rexdale  ...                         55054
# ..                                 ...  ...                           ...
# 136                          West Hill  ...                         49341
# 137                             Woburn  ...                         51539
# 138                      Eglinton East  ...                         44772
# 139                Scarborough Village  ...                         45109
# 140                          Guildwood  ...                         75351
#
# [140 rows x 85 columns]

# %%
def pop_density(row):
  return float(row['Total Population']) / float(row['Total Area'])

# %%
new_data['Population Density'] = new_data.apply (lambda row: pop_density(row), axis=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
new_data
# Out:
# 0                        Neighbourhood  ... Population Density
# 1               West Humber-Clairville  ...        1072.283151
# 2    Mount Olive-Silverstone-Jamestown  ...        6984.782609
# 3         Thistletown-Beaumond Heights  ...        2919.117647
# 4                      Rexdale-Kipling  ...        4290.000000
# 5                     Elms-Old Rexdale  ...        3255.172414
# ..                                 ...  ...                ...
# 136                          West Hill  ...        2670.312500
# 137                             Woburn  ...        3347.950820
# 138                      Eglinton East  ...        6995.312500
# 139                Scarborough Village  ...        5027.419355
# 140                          Guildwood  ...        2638.157895
#
# [140 rows x 86 columns]

# %%
import matplotlib

# %%
new_data2 = pd.read_csv('https://raw.githubusercontent.com/Kaartik7/ISSC_competition-/pomegranate02-patch-1/to%20csv/population%202011.csv')

# %%
names = new_data2.iloc[0]

# %%
new_data2 = new_data2[1:]

# %%
new_data2.columns = names

# %%
new_data2['Population Density'] = new_data2.apply (lambda row: pop_density(row), axis=1)

# %%
new_data2
# Out:
# 0                        Neighbourhood  ... Population Density
# 1               West Humber-Clairville  ...        1133.266866
# 2    Mount Olive-Silverstone-Jamestown  ...        7128.260870
# 3         Thistletown-Beaumond Heights  ...        2982.352941
# 4                      Rexdale-Kipling  ...        4194.000000
# 5                     Elms-Old Rexdale  ...        3293.103448
# ..                                 ...  ...                ...
# 136                          West Hill  ...        2765.625000
# 137                             Woburn  ...        4372.950820
# 138                      Eglinton East  ...        7134.375000
# 139                Scarborough Village  ...        5359.677419
# 140                          Guildwood  ...        2582.894737
#
# [140 rows x 40 columns]

# %%
data2008 = new_data[['Neighbourhood','Total Population', 'Population Density' ]]

# %%
data2011 = new_data[['Total Population', 'Population Density' ]]

# %%
data2011
# Out:
# 0   Total Population  Population Density
# 1              32265         1072.283151
# 2              32130         6984.782609
# 3               9925         2919.117647
# 4              10725         4290.000000
# 5               9440         3255.172414
# ..               ...                 ...
# 136            25635         2670.312500
# 137            40845         3347.950820
# 138            22385         6995.312500
# 139            15585         5027.419355
# 140            10025         2638.157895
#
# [140 rows x 2 columns]

# %%
data2008.columns = ['Neighbourhood','Total Population 2008 ', 'Population Density 2008' ]

# %%
data2008
# Out:
#                          Neighbourhood  ... Population Density 2008
# 1               West Humber-Clairville  ...             1072.283151
# 2    Mount Olive-Silverstone-Jamestown  ...             6984.782609
# 3         Thistletown-Beaumond Heights  ...             2919.117647
# 4                      Rexdale-Kipling  ...             4290.000000
# 5                     Elms-Old Rexdale  ...             3255.172414
# ..                                 ...  ...                     ...
# 136                          West Hill  ...             2670.312500
# 137                             Woburn  ...             3347.950820
# 138                      Eglinton East  ...             6995.312500
# 139                Scarborough Village  ...             5027.419355
# 140                          Guildwood  ...             2638.157895
#
# [140 rows x 3 columns]

# %%
data2011.columns = ['Total Population 2011 ', 'Population Density 2011' ]

# %%
data2011
# Out:
#     Total Population 2011   Population Density 2011
# 1                    32265              1072.283151
# 2                    32130              6984.782609
# 3                     9925              2919.117647
# 4                    10725              4290.000000
# 5                     9440              3255.172414
# ..                     ...                      ...
# 136                  25635              2670.312500
# 137                  40845              3347.950820
# 138                  22385              6995.312500
# 139                  15585              5027.419355
# 140                  10025              2638.157895
#
# [140 rows x 2 columns]

# %%
frames = [data2008, data2011]

# %%
pd.concat(frames)
# Out:
#                          Neighbourhood  ... Population Density 2011
# 1               West Humber-Clairville  ...                     NaN
# 2    Mount Olive-Silverstone-Jamestown  ...                     NaN
# 3         Thistletown-Beaumond Heights  ...                     NaN
# 4                      Rexdale-Kipling  ...                     NaN
# 5                     Elms-Old Rexdale  ...                     NaN
# ..                                 ...  ...                     ...
# 136                                NaN  ...             2670.312500
# 137                                NaN  ...             3347.950820
# 138                                NaN  ...             6995.312500
# 139                                NaN  ...             5027.419355
# 140                                NaN  ...             2638.157895
#
# [280 rows x 5 columns]

# %%
result = pd.concat(frames, axis=1)

# %%
result
# Out:
#                          Neighbourhood  ... Population Density 2011
# 1               West Humber-Clairville  ...             1072.283151
# 2    Mount Olive-Silverstone-Jamestown  ...             6984.782609
# 3         Thistletown-Beaumond Heights  ...             2919.117647
# 4                      Rexdale-Kipling  ...             4290.000000
# 5                     Elms-Old Rexdale  ...             3255.172414
# ..                                 ...  ...                     ...
# 136                          West Hill  ...             2670.312500
# 137                             Woburn  ...             3347.950820
# 138                      Eglinton East  ...             6995.312500
# 139                Scarborough Village  ...             5027.419355
# 140                          Guildwood  ...             2638.157895
#
# [140 rows x 5 columns]

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(result['Neighbourhood'],result['Population Density 2008'])
# Out:
# <BarContainer object of 140 artists>

# %%
plt.bar(result['Neighbourhood'],result['Population Density 2008'], bottom = result['Population Density 2008'])
# Out:
# <BarContainer object of 140 artists>

# %%
plt.bar(result['Neighbourhood'],result['Population Density 2008'])
plt.bar(result['Neighbourhood'],result['Population Density 2008'], bottom = result['Population Density 2008'])
plt.show()

# %%
new_result = result.sort_values(by=['Population Density 2011'], ascending=False)

# %%
new_result[1:11]
# Out:
#                Neighbourhood  ... Population Density 2011
# 104      Mount Pleasant West  ...            18257.692308
# 75     Church-Yonge Corridor  ...            17407.142857
# 72               Regent Park  ...            17308.333333
# 61             Taylor-Massey  ...            13827.272727
# 69               Blake-Jones  ...            13211.111111
# 78      Kensington-Chinatown  ...            11393.333333
# 73                 Moss Park  ...            11057.142857
# 88           High Park North  ...            11036.842105
# 84           Little Portugal  ...            10100.000000
# 80   Palmerston-Little Italy  ...             9839.285714
#
# [10 rows x 5 columns]

# %%
plotting = new_result[1:11]
plt.bar(plotting['Neighbourhood'],plotting['Population Density 2008'])
plt.bar(plotting['Neighbourhood'],plotting['Population Density 2008'], bottom = plotting['Population Density 2008'])
plt.show()

# %%
transport = pd.read_csv('https://raw.githubusercontent.com/Kaartik7/ISSC_competition-/pomegranate02-patch-1/to%20csv/transport.csv')

# %%
transport
# Out:
#                          Neighbourhood  ...  Road Volume
# 0               West Humber-Clairville  ...  5956.638889
# 1    Mount Olive-Silverstone-Jamestown  ...  3514.166667
# 2         Thistletown-Beaumond Heights  ...  3545.000000
# 3                      Rexdale-Kipling  ...  7621.333333
# 4                     Elms-Old Rexdale  ...  4115.500000
# ..                                 ...  ...          ...
# 135                          West Hill  ...  3824.181818
# 136                             Woburn  ...  4656.600000
# 137                      Eglinton East  ...  3086.000000
# 138                Scarborough Village  ...  2111.600000
# 139                          Guildwood  ...  2114.875000
#
# [140 rows x 8 columns]

# %%
transport[['Neighbourhood','Road Volume']]
# Out:
#                          Neighbourhood  Road Volume
# 0               West Humber-Clairville  5956.638889
# 1    Mount Olive-Silverstone-Jamestown  3514.166667
# 2         Thistletown-Beaumond Heights  3545.000000
# 3                      Rexdale-Kipling  7621.333333
# 4                     Elms-Old Rexdale  4115.500000
# ..                                 ...          ...
# 135                          West Hill  3824.181818
# 136                             Woburn  4656.600000
# 137                      Eglinton East  3086.000000
# 138                Scarborough Village  2111.600000
# 139                          Guildwood  2114.875000
#
# [140 rows x 2 columns]

# %%
new_transport = transport[['Neighbourhood','Road Volume']]

# %%
new_transport = new_transport.sort_values(by=['Road Volume'], ascending=False)[1:11]

# %%
new_transport
# Out:
#                          Neighbourhood   Road Volume
# 107               Briar Hill-Belgravia  11837.285710
# 48               Bayview Woods-Steeles  10812.000000
# 55                  Leaside-Bennington   8701.583333
# 27                              Rustic   7692.000000
# 3                      Rexdale-Kipling   7621.333333
# 72                           Moss Park   7509.333333
# 69                     South Riverdale   7386.200000
# 23                         Black Creek   7326.300000
# 40   Bridle Path-Sunnybrook-York Mills   7224.500000
# 96                      Yonge-St.Clair   7116.000000

# %%
plt.bar(new_transport['Neighbourhood'], new_transport['Road Volume'])
plt.show()

# %%
fares = pd.read_csv('https://raw.githubusercontent.com/Kaartik7/ISSC_competition-/pomegranate02-patch-1/to%20csv/transport%20fares.csv')

# %%
fares
# Out:
#       REF_DATE                        GEO  ... TERMINATED DECIMALS
# 0    2006/2007                     Canada  ...        NaN        1
# 1    2006/2007                     Canada  ...        NaN        1
# 2    2006/2007                     Canada  ...        NaN        1
# 3    2006/2007  Newfoundland and Labrador  ...        NaN        1
# 4    2006/2007  Newfoundland and Labrador  ...        NaN        1
# ..         ...                        ...  ...        ...      ...
# 415  2015/2016      Northwest Territories  ...        NaN        1
# 416  2015/2016      Northwest Territories  ...        NaN        1
# 417  2015/2016                    Nunavut  ...        NaN        1
# 418  2015/2016                    Nunavut  ...        NaN        1
# 419  2015/2016                    Nunavut  ...        NaN        1
#
# [420 rows x 15 columns]

# %%
new_fares = fares[fares['REF_DATE'] == '2015/2016']

# %%
new_fares
# Out:
#       REF_DATE                        GEO  ... TERMINATED DECIMALS
# 378  2015/2016                     Canada  ...        NaN        1
# 379  2015/2016                     Canada  ...        NaN        1
# 380  2015/2016                     Canada  ...        NaN        1
# 381  2015/2016  Newfoundland and Labrador  ...        NaN        1
# 382  2015/2016  Newfoundland and Labrador  ...        NaN        1
# 383  2015/2016  Newfoundland and Labrador  ...        NaN        1
# 384  2015/2016       Prince Edward Island  ...        NaN        1
# 385  2015/2016       Prince Edward Island  ...        NaN        1
# 386  2015/2016       Prince Edward Island  ...        NaN        1
# 387  2015/2016                Nova Scotia  ...        NaN        1
# 388  2015/2016                Nova Scotia  ...        NaN        1
# 389  2015/2016                Nova Scotia  ...        NaN        1
# 390  2015/2016              New Brunswick  ...        NaN        1
# ...

# %%
new_fares = new_fares[new_fares['Statistics'] == 'Per capita transport expenditures']

# %%
new_fares
# Out:
#       REF_DATE                        GEO  ... TERMINATED DECIMALS
# 380  2015/2016                     Canada  ...        NaN        1
# 383  2015/2016  Newfoundland and Labrador  ...        NaN        1
# 386  2015/2016       Prince Edward Island  ...        NaN        1
# 389  2015/2016                Nova Scotia  ...        NaN        1
# 392  2015/2016              New Brunswick  ...        NaN        1
# 395  2015/2016                     Quebec  ...        NaN        1
# 398  2015/2016                    Ontario  ...        NaN        1
# 401  2015/2016                   Manitoba  ...        NaN        1
# 404  2015/2016               Saskatchewan  ...        NaN        1
# 407  2015/2016                    Alberta  ...        NaN        1
# 410  2015/2016           British Columbia  ...        NaN        1
# 413  2015/2016                      Yukon  ...        NaN        1
# 416  2015/2016      Northwest Territories  ...        NaN        1
# ...

# %%
plt.bar(new_fares['GEO'], new_fares['VALUE'],color='orange')
plt.show()

# %%
new_fares = fares[(fares['GEO'] == 'Ontario') & (fares['Statistics'] == 'Per capita transport expenditures')]

# %%
new_fares
# Out:
#       REF_DATE      GEO        DGUID  ... SYMBOL TERMINATED  DECIMALS
# 20   2006/2007  Ontario  2016A000235  ...    NaN        NaN         1
# 62   2007/2008  Ontario  2016A000235  ...    NaN        NaN         1
# 104  2008/2009  Ontario  2016A000235  ...    NaN        NaN         1
# 146  2009/2010  Ontario  2016A000235  ...    NaN        NaN         1
# 188  2010/2011  Ontario  2016A000235  ...    NaN        NaN         1
# 230  2011/2012  Ontario  2016A000235  ...    NaN        NaN         1
# 272  2012/2013  Ontario  2016A000235  ...    NaN        NaN         1
# 314  2013/2014  Ontario  2016A000235  ...    NaN        NaN         1
# 356  2014/2015  Ontario  2016A000235  ...    NaN        NaN         1
# 398  2015/2016  Ontario  2016A000235  ...    NaN        NaN         1
#
# [10 rows x 15 columns]

# %%
plt.plot(new_fares['REF_DATE'], new_fares['VALUE'])
plt.scatter(new_fares['REF_DATE'], new_fares['VALUE'])
plt.show()
